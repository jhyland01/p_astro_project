# %% [markdown]
# ---
# Following the Lynch et al paper https://iopscience.iop.org/article/10.3847/2041-8213/aacf9f
#
# "We find that the gravitational-wave alert threshold change that would roughly double the number of detectable astrophysical events would increase the false-alarm rate by more than 5 orders of magnitude from 1 per 100 years to more than 1000 per year."
#
# "We argue that EM follow-up thresholds for low-significance candidates should be set on the basis of alert purity (Pastro) and not false-alarm rate."
#
# $FAR = FAR_8 \times exp [-\frac{\rho - 8}{\alpha}]$
#
# * $FAR_8$ is the false alarm rate at a network ranking statistic $\rho = 8$
# * $\alpha$ is a scale parameter that determines the steepness of the fall off
#
# "For BBH we find α = 0.18 and FAR8 = 5500 yr−1"
#
# ---
# From Nitz et al. 2017 https://doi.org/10.3847/1538-4357/aa8f50
#
# The SNR and signal consistency tests (Allen paper) result in the detection statistic.
#
# "We present a new detection statistic that reduces the false alarm rate of the search across the entire target signal space: binary neutron stars, binary black holes, and neutron star–black hole binaries. This detection statistic uses information from both the physical parameters of the gravitational-wave signal and the expected distribution of the noise background to rescale the “combined effective signal-to-noise ratio” used previously by the PyCBC search."
#
# "The detection statistic used in Advanced LIGO’s first observing run was the quadrature sum of the re-weighted signal-to-noise ratio $\hat{\rho}$ observed in each detector, denoted $\hat{\rho_c}$"
#
# $\hat{\rho} = \frac{\rho}{[1+(\chi^2)^3]^{1/6}}$
#
# The $\chi^2$ here is to test the `signal' against the waveform. This test is less effective in the high mass end of CBCs since these signals are shorter and can more easily resemble a noice event.
# * does that mean the relation between SNR and FAR has some spread that tracks the mass of the system?
#
# "The non-stationarity of the detectors’ noise means that it is impossible to construct an analytic model of the search’s false alarm rate."
#
# They look like they use PyCBC data to estimate the FAR for the run.
#
# ---
#
# ### Questions to look into
# * How do I determine my own $\alpha$ ?
#     * just fit the suggest model to the FAR/SNR
#     * maybe a new model
# * How does $\rho$ relate to the optimal SNR?
# * How do you determine $FAR_8$?
#     * same as above for $\alpha$
#
# ### To do:
# * look for examples of FAR estimation for observing runs
#     * probably linked in LIGO papers
#
# The optimal matched filter signal-to-noise ratio squared:
#
# $\rho^{2}_{opt} = <\mu , \mu>$
#
# The SNR that bilby outputs is the matched filter SNR.
# The comparisons done in the Lynch and Nitz papers use the ranking statictic $\hat{\rho}$.
# * What is the SNR provided in the data release?
#     * in the xml files they provide a $\chi^2$ value and an SNR for each event in the sngl_inspiral table so I can calculate the $\hat{\rho}$ if that is desired
#
# "The snr column MUST report the absolute value of the complex matched filter SNR of the best-matching template. It MUST NOT report a modified SNR-like quantity such as newSNR." from https://lscsoft.docs.ligo.org/ligo.skymap/interface.html
# * so these are the complex-matched filter snrs
# * therefore I am being consistent, the snrs from bilby are the same as those from the data release. I can therefore produce some kind of approximate relationship to take SNR to FAR, fitted to the data release info and apply this to my sampled SNRs.

# %%
import pandas as pd
import numpy as np
samples = pd.read_csv('params_inc_SNR.csv', index_col=0)
samples['net_snr'] = np.sqrt(samples['H1_snr']**2 + samples['L1_snr']**2 +samples['V1_snr']**2)

# %%
# ranking statistic function
def rho(SNR, chi):
    rho_hat = SNR/(1+(chi**2)**3)**(1/6)
    return rho_hat

# %%
samples[['net_snr','H1_snr', 'L1_snr', 'V1_snr' ]]
# Out:
#       net_snr    H1_snr    L1_snr    V1_snr
# 0    4.715177  2.647601  3.696115  1.249735
# 1    0.762437  0.497399  0.437930  0.376991
# 2    1.630003  1.109248  0.902239  0.782588
# 3    0.953321  0.658860  0.642250  0.249479
# 4    1.492217  1.001577  0.942943  0.578285
# ..        ...       ...       ...       ...
# 994  2.149868  0.914275  1.272485  1.472011
# 995  1.126950  0.661138  0.693493  0.593278
# 996  2.122559  1.574888  1.418618  0.111846
# 997  1.292417  0.788730  0.648067  0.792626
# 998  2.145050  0.559532  0.232423  2.057704
#
# [999 rows x 4 columns]

# %%
# write the FAR conversion as a function
def SNR_to_FAR(snr, FAR8=5500, alpha=0.18):
    """Calculate the FAR using the parameterisations from the Lynch paper"""
    FAR = FAR8*np.exp(-(snr-8)/alpha)
    return FAR

# use this parameterisation to estimate some FARs
samples['lynch_FAR'] = SNR_to_FAR(samples['net_snr'])

# %%
# use this parameterisation to estimate some FARs
samples['lynch_FAR'] = SNR_to_FAR(samples['net_snr'])

# %%
SNR_to_FAR(10)
# Out:
# 0.08219936188629798

# %%
import matplotlib.pyplot as plt
plt.semilogy(samples['net_snr'], samples['FAR'], '.', markersize=3)
plt.ylabel('FAR, yr$^-1$')
plt.xlabel('Network Combined optimal SNR')
plt.grid()

# %% [markdown]
# Up to here I've been using the combined SNR as my ranking statistic, this doesn't seem to quite be what is being used in the Nitz paper.
#
# Nitz uses the quadrature sum of the **reweighted SNR, $\hat{\rho}$**:
#
# $\hat{\rho} = \frac{\rho}{[1+(\chi^2)^3]^{1/6}}$
#
# So I need to look at the chi_2 statistic:
#
# * check PyCBC documentation
# * check bilby documentation

# %% [markdown]
# ### Look at the data release SNRs and FARs

# %%
#!wget -O ../data_release.csv https://www.gw-openscience.org/eventapi/csv/GWTC/ -P ..

data_release = pd.read_csv('../data_release.csv', index_col=0)
data_release.tail()
# Out:
#                          commonName  version catalog.shortName           GPS  \
# id
# GW200306_093714-v1  GW200306_093714        1  GWTC-3-confident  1.267523e+09
# GW200308_173609-v1  GW200308_173609        1  GWTC-3-confident  1.267724e+09
# GW200311_115853-v1  GW200311_115853        1  GWTC-3-confident  1.267963e+09
# GW200316_215756-v1  GW200316_215756        1  GWTC-3-confident  1.268431e+09
# GW200322_091133-v1  GW200322_091133        1  GWTC-3-confident  1.268904e+09
#
#                    reference  \
# id
# GW200306_093714-v1  /GWTC-3/
# GW200308_173609-v1  /GWTC-3/
# GW200311_115853-v1  /GWTC-3/
# GW200316_215756-v1  /GWTC-3/
# GW200322_091133-v1  /GWTC-3/
#
#                                                               jsonurl  \
# id
# GW200306_093714-v1  https://www.gw-openscience.org/eventapi/json/G...
# GW200308_173609-v1  https://www.gw-openscience.org/eventapi/json/G...
# GW200311_115853-v1  https://www.gw-openscience.org/eventapi/json/G...
# GW200316_215756-v1  https://www.gw-openscience.org/eventapi/json/G...
# GW200322_091133-v1  https://www.gw-openscience.org/eventapi/json/G...
#
#                     mass_1_source  mass_1_source_lower  mass_1_source_upper  \
# id
# GW200306_093714-v1           28.3                 -7.7                 17.1
# GW200308_173609-v1           36.4                 -9.6                 11.2
# GW200311_115853-v1           34.2                 -3.8                  6.4
# GW200316_215756-v1           13.1                 -2.9                 10.2
# GW200322_091133-v1           34.0                -18.0                 48.0
#
#                     mass_2_source  ...  redshift_upper        far  far_lower  \
# id                                 ...
# GW200306_093714-v1           14.8  ...            0.24   24.00000        NaN
# GW200308_173609-v1           13.8  ...            0.32    2.40000        NaN
# GW200311_115853-v1           27.7  ...            0.05    0.00001        NaN
# GW200316_215756-v1            7.8  ...            0.08    0.00001        NaN
# GW200322_091133-v1           14.0  ...            0.84  140.00000        NaN
#
#                     far_upper   p_astro  p_astro_lower  p_astro_upper  \
# id
# GW200306_093714-v1        NaN  0.240040            NaN            NaN
# GW200308_173609-v1        NaN  0.856600            NaN            NaN
# GW200311_115853-v1        NaN  0.990000            NaN            NaN
# GW200316_215756-v1        NaN  0.990000            NaN            NaN
# GW200322_091133-v1        NaN  0.077572            NaN            NaN
#
#                     final_mass_source  final_mass_source_lower  \
# id
# GW200306_093714-v1               41.7                     -6.9
# GW200308_173609-v1               47.4                     -7.7
# GW200311_115853-v1               59.0                     -3.9
# GW200316_215756-v1               20.2                     -1.9
# GW200322_091133-v1               53.0                    -26.0
#
#                     final_mass_source_upper
# id
# GW200306_093714-v1                     12.3
# GW200308_173609-v1                     11.1
# GW200311_115853-v1                      4.8
# GW200316_215756-v1                      7.4
# GW200322_091133-v1                     38.0
#
# [5 rows x 42 columns]

# %%
fig, ax = plt.subplots(figsize = (9, 6))
sc = ax.scatter(x=data_release['network_matched_filter_snr'], y=(data_release['far']), c=data_release['p_astro'], cmap='cool', label='real signals')
ax.set_yscale("log")
plt.ylabel('FAR, yr$^-1$')
plt.xlabel('Network matched filter SNR')
plt.semilogy(samples['net_snr'], samples['FAR'], '-', markersize=3, label=r'samples, $\alpha = 0.18$')
plt.grid()
plt.xlim((6,13))
plt.ylim((1e-4,1e7))
fig.colorbar(sc, label='$p_{astro}$')
plt.legend()

# %%
plt.hist(data_release['network_matched_filter_snr'], density=True, histtype='step', cumulative=True)
plt.xlabel('SNR')
plt.title('Cumulative Histogram of SNRs')
# Out:
# Text(0.5, 1.0, 'Cumulative Histogram of SNRs')

# %%
data_release['network_matched_filter_snr'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### Next steps
# * download the full catalogs, the events **do not** need to be actual signals, we are just interested in the relationship between FAR and SNR here
# * confirm the form of the detection statistic $\rho$
#     * Maggiore, $\chi^2$
# * fit the FAR, $\rho$ relationship for a better $\alpha$
#     * this will involve removing those which have saturated

# %%
#!wget -O ../gwtc3_candidates https://zenodo.org/record/5546665/files/search_data.tar.gz?download=1 -P ..

# !tar -xvzf ../gwtc3_candidates -C ../GWTC3_search_prods

# extract for the highmass folder
pathToData_3_hm = '/data/wiay/johnny/phd1/GWTC3_search_prods/search_data_products/pycbc_highmass/'
full_list = os.listdir(pathToData_3_hm)
# import xml.etree.ElementTree
len(full_list)

snr_3_hm=[]
# far_3_hm=[]
combined_far_3_hm=[]
jul_yr = 31557600

for file in full_list:
    try:
        # read from the xml the last object in the coinc_inspiral:table which is the snr
        snr_3_hm.append(float(pd.read_xml(pathToData_3_hm+file)['Stream'][6].split(",")[-1]))
        # we also want the combined_far[1] and the false_alarm_rate[4]
        # far_3_hm.append(float(pd.read_xml(pathToData_3_hm+file)['Stream'][6].split(",")[4]))
        combined_far_3_hm.append(float(pd.read_xml(pathToData_3_hm+file)['Stream'][6].split(",")[1])*jul_yr)
    except:
        print(file)

# extract for the allsky folder
pathToData_3_as = '/data/wiay/johnny/phd1/GWTC3_search_prods/search_data_products/pycbc_all_sky/'
full_list = os.listdir(pathToData_3_as)
# import xml.etree.ElementTree
len(full_list)

snr_3_as=[]
# far_3_as=[]
combined_far_3_as=[]


for file in full_list:
    try:
        # read from the xml the last object in the coinc_inspiral:table which is the snr
        snr_3_as.append(float(pd.read_xml(pathToData_3_as+file)['Stream'][6].split(",")[-1]))
        # we also want the combined_far[1] and the false_alarm_rate[4]
        # far_3_as.append(float(pd.read_xml(pathToData_3_as+file)['Stream'][6].split(",")[4]))
        combined_far_3_as.append(float(pd.read_xml(pathToData_3_as+file)['Stream'][6].split(",")[1])*jul_yr)
    except:
        print(file)

# extract for the mbta folder
pathToData_3_mbta = '/data/wiay/johnny/phd1/GWTC3_search_prods/search_data_products/mbta_all_sky/'
full_list = os.listdir(pathToData_3_mbta)
# import xml.etree.ElementTree
len(full_list)

snr_3_mbta=[]
# far_3_mbta=[]
combined_far_3_mbta=[]

for file in full_list:
    try:
        # read from the xml the last object in the coinc_inspiral:table which is the snr
        snr_3_mbta.append(float(pd.read_xml(pathToData_3_mbta+file)['Stream'][3].split(",")[-3]))
        # we also want the combined_far[1] and the false_alarm_rate[4]
        # far_3_mbta.append(float(pd.read_xml(pathToData_3_mbta+file)['Stream'][3].split(",")[-2]))
        combined_far_3_mbta.append(float(pd.read_xml(pathToData_3_mbta+file)['Stream'][3].split(",")[-1])*jul_yr)
    except:
        print(file)

# extract for the gstlal folder
pathToData_3_gst = '/data/wiay/johnny/phd1/GWTC3_search_prods/search_data_products/gstlal_allsky/'
full_list = os.listdir(pathToData_3_gst)
# import xml.etree.ElementTree
len(full_list)

snr_3_gst=[]
# far_3_gst=[]
combined_far_3_gst=[]


for file in full_list:
    try:
        # read from the xml the last object in the coinc_inspiral:table which is the snr
        snr_3_gst.append(float(pd.read_xml(pathToData_3_gst+file)['Stream'][5].split(",")[-1]))
        # we also want the combined_far[1] and the false_alarm_rate[4]
        # far_3_gst.append(float(pd.read_xml(pathToData_3_gst+file)['Stream'][5].split(",")[4]))
        combined_far_3_gst.append(float(pd.read_xml(pathToData_3_gst+file)['Stream'][5].split(",")[1])*jul_yr)
    except:
        print(file)
# Out:
# skymaps_ligolw
# skymaps
# o3a_pastro
# pastro
# skymaps_ligolw
# skymaps
# o3a_pastro
# pastro
# skymaps
# o3a_pastro
# pastro
# skymaps
# o3a_pastro
# pastro

# %%
# the same as above now for the GWTC 2.1 release
# !wget -O ../search_data_GWTC2p1.tar.gz https://zenodo.org/record/5759108/files/search_data_GWTC2p1.tar.gz?download=1 -P ..

# !tar -xvzf ../search_data_GWTC2p1.tar.gz -C ../GWTC2p1_search_prods

pathToData_21_hm = '/data/wiay/johnny/phd1//GWTC2p1_search_prods/search_data_products/pycbc_highmass/'
full_list = os.listdir(pathToData_21_hm)
len(full_list)

snr_21_hm=[]
# far_21_hm=[]
combined_far_21_hm=[]
jul_yr = 31557600

for file in full_list:
    try:
        # read from the xml the last object in the coinc_inspiral:table which is the snr
        snr_21_hm.append(float(pd.read_xml(pathToData_21_hm+file)['Stream'][6].split(",")[-1]))
        # we also want the combined_far[1] and the false_alarm_rate[4]
        # far_21_hm.append(float(pd.read_xml(pathToData_21_hm+file)['Stream'][6].split(",")[4]))
        combined_far_21_hm.append(float(pd.read_xml(pathToData_21_hm+file)['Stream'][6].split(",")[1])*jul_yr)
    except:
        print(file)

# extract for the allsky folder
pathToData_21_as = '/data/wiay/johnny/phd1/GWTC2p1_search_prods/search_data_products/pycbc_all_sky/'
full_list = os.listdir(pathToData_21_as)
# import xml.etree.ElementTree
len(full_list)

snr_21_as=[]
# far_21_as=[]
combined_far_21_as=[]


for file in full_list:
    try:
        # read from the xml the last object in the coinc_inspiral:table which is the snr
        snr_21_as.append(float(pd.read_xml(pathToData_21_as+file)['Stream'][6].split(",")[-1]))
        # we also want the combined_far[1] and the false_alarm_rate[4]
        # far_21_as.append(float(pd.read_xml(pathToData_21_as+file)['Stream'][6].split(",")[4]))
        combined_far_21_as.append(float(pd.read_xml(pathToData_21_as+file)['Stream'][6].split(",")[1])*jul_yr)
    except:
        print(file)

# extract for the mbta folder
# these xml files were .gz so navigated to the folder in a terminal and gzip -d *.gz to uncompress them
pathToData_21_mbta = '/data/wiay/johnny/phd1/GWTC2p1_search_prods/search_data_products/mbta_all_sky/'
full_list = os.listdir(pathToData_21_mbta)
# import xml.etree.ElementTree
len(full_list)

snr_21_mbta=[]
# far_21_mbta=[]
combined_far_21_mbta=[]

for file in full_list:
    try:
        xml_file = gzip.open(file,'r')
        # read from the xml the last object in the coinc_inspiral:table which is the snr
        snr_21_mbta.append(float(pd.read_xml(pathToData_21_mbta+file)['Stream'][3].split(",")[-3]))
        # we also want the combined_far[1] and the false_alarm_rate[4]
        # far_21_mbta.append(float(pd.read_xml(pathToData_21_mbta+file)['Stream'][3].split(",")[-2]))
        combined_far_21_mbta.append(float(pd.read_xml(pathToData_21_mbta+file)['Stream'][3].split(",")[-1])*jul_yr)
    except:
        print(file)

# extract for the gstlal folder
pathToData_21_gst = '/data/wiay/johnny/phd1/GWTC2p1_search_prods/search_data_products/gstlal_all_sky/'
full_list = os.listdir(pathToData_21_gst)
# import xml.etree.ElementTree
len(full_list)

snr_21_gst=[]
# far_21_gst=[]
combined_far_21_gst=[]


for file in full_list:
    try:
        # read from the xml the last object in the coinc_inspiral:table which is the snr
        snr_21_gst.append(float(pd.read_xml(pathToData_21_gst+file)['Stream'][5].split(",")[-1]))
        # we also want the combined_far[1] and the false_alarm_rate[4]
        # far_21_gst.append(float(pd.read_xml(pathToData_21_gst+file)['Stream'][5].split(",")[4]))
        combined_far_21_gst.append(float(pd.read_xml(pathToData_21_gst+file)['Stream'][5].split(",")[1])*jul_yr)
    except:
        print(file)
# Out:
# skymaps_ligolw
# skymaps
# pastro
# skymaps_ligolw
# skymaps
# pastro
# H1L1-MBTA_AllSky-1244478004-1.xml
# H1L1-MBTA_AllSky-1249662203-1.xml
# H1L1-MBTA_AllSky-1242580186-1.xml
# H1L1-MBTA_AllSky-1244639322-1.xml
# H1L1-MBTA_AllSky-1244725100-1.xml
# H1L1-MBTA_AllSky-1249485257-1.xml
# H1L1-MBTA_AllSky-1242442967-1.xml
# H1L1-MBTA_AllSky-1248328952-1.xml
# H1L1-MBTA_AllSky-1252699636-1.xml
# L1V1-MBTA_AllSky-1245646385-1.xml
# H1L1-MBTA_AllSky-1252323342-1.xml
# H1L1-MBTA_AllSky-1246471145-1.xml
# H1L1-MBTA_AllSky-1250171712-1.xml
# H1V1-MBTA_AllSky-1239382462-1.xml
# H1L1-MBTA_AllSky-1248181015-1.xml
# H1L1-MBTA_AllSky-1252000665-1.xml
# H1L1-MBTA_AllSky-1238617829-1.xml
# H1L1-MBTA_AllSky-1248467557-1.xml
# H1L1-MBTA_AllSky-1248242632-1.xml
# H1L1-MBTA_AllSky-1246510114-1.xml
# H1L1-MBTA_AllSky-1240297822-1.xml
# H1L1-MBTA_AllSky-1245659748-1.xml
# H1L1-MBTA_AllSky-1238411990-1.xml
# H1V1-MBTA_AllSky-1253497461-1.xml
# H1L1-MBTA_AllSky-1250422367-1.xml
# H1L1-MBTA_AllSky-1245596642-1.xml
# H1L1-MBTA_AllSky-1250082200-1.xml
# H1L1-MBTA_AllSky-1250056239-1.xml
# H1L1-MBTA_AllSky-1249833533-1.xml
# H1L1-MBTA_AllSky-1252942066-1.xml
# H1L1-MBTA_AllSky-1243646917-1.xml
# H1L1-MBTA_AllSky-1252069762-1.xml
# H1L1V1-MBTA_AllSky-1239063925-1.xml
# H1L1-MBTA_AllSky-1249826603-1.xml
# H1L1V1-MBTA_AllSky-1250582792-1.xml
# H1L1-MBTA_AllSky-1238533707-1.xml
# H1L1-MBTA_AllSky-1252343416-1.xml
# H1L1-MBTA_AllSky-1240327333-1.xml
# H1L1-MBTA_AllSky-1240944862-1.xml
# H1L1-MBTA_AllSky-1250108745-1.xml
# H1L1-MBTA_AllSky-1243543887-1.xml
# H1L1V1-MBTA_AllSky-1246048404-1.xml
# H1L1-MBTA_AllSky-1238183928-1.xml
# H1L1-MBTA_AllSky-1246527224-1.xml
# H1L1V1-MBTA_AllSky-1253427348-1.xml
# H1L1-MBTA_AllSky-1243614787-1.xml
# H1L1-MBTA_AllSky-1243533585-1.xml
# H1L1-MBTA_AllSky-1252598850-1.xml
# H1L1-MBTA_AllSky-1243430420-1.xml
# H1L1-MBTA_AllSky-1250343387-1.xml
# H1L1V1-MBTA_AllSky-1243739581-1.xml
# H1L1-MBTA_AllSky-1252366378-1.xml
# H1L1-MBTA_AllSky-1248184675-1.xml
# H1L1V1-MBTA_AllSky-1240986884-1.xml
# H1L1-MBTA_AllSky-1240724451-1.xml
# H1L1-MBTA_AllSky-1240329848-1.xml
# H1L1-MBTA_AllSky-1244291942-1.xml
# H1L1-MBTA_AllSky-1245792371-1.xml
# H1L1-MBTA_AllSky-1252802382-1.xml
# H1L1-MBTA_AllSky-1240733169-1.xml
# H1L1-MBTA_AllSky-1250735023-1.xml
# H1L1-MBTA_AllSky-1242421617-1.xml
# L1V1-MBTA_AllSky-1249903249-1.xml
# H1L1-MBTA_AllSky-1241768899-1.xml
# H1L1-MBTA_AllSky-1250684089-1.xml
# H1L1-MBTA_AllSky-1242315362-1.xml
# H1L1-MBTA_AllSky-1253885759-1.xml
# H1L1-MBTA_AllSky-1251979536-1.xml
# H1L1-MBTA_AllSky-1242683952-1.xml
# H1L1-MBTA_AllSky-1248688647-1.xml
# H1L1-MBTA_AllSky-1239198206-1.xml
# H1L1-MBTA_AllSky-1240556021-1.xml
# H1L1-MBTA_AllSky-1252627040-1.xml
# H1L1-MBTA_AllSky-1251236508-1.xml
# H1L1-MBTA_AllSky-1246085488-1.xml
# H1L1-MBTA_AllSky-1249072561-1.xml
# H1L1V1-MBTA_AllSky-1247580401-1.xml
# H1L1-MBTA_AllSky-1253741273-1.xml
# H1L1-MBTA_AllSky-1252544438-1.xml
# H1L1-MBTA_AllSky-1250109181-1.xml
# H1L1-MBTA_AllSky-1249364701-1.xml
# H1L1-MBTA_AllSky-1245312151-1.xml
# H1L1-MBTA_AllSky-1239825021-1.xml
# H1L1-MBTA_AllSky-1246655423-1.xml
# H1L1-MBTA_AllSky-1253449135-1.xml
# H1L1-MBTA_AllSky-1253718752-1.xml
# H1L1-MBTA_AllSky-1249385229-1.xml
# H1L1-MBTA_AllSky-1248847613-1.xml
# H1L1V1-MBTA_AllSky-1251897220-1.xml
# H1L1-MBTA_AllSky-1252113997-1.xml
# H1L1-MBTA_AllSky-1253753760-1.xml
# H1L1-MBTA_AllSky-1240423628-1.xml
# H1L1-MBTA_AllSky-1243786474-1.xml
# H1L1-MBTA_AllSky-1245571325-1.xml
# H1L1-MBTA_AllSky-1242474881-1.xml
# H1L1-MBTA_AllSky-1249330158-1.xml
# H1L1V1-MBTA_AllSky-1242364630-1.xml
# H1L1-MBTA_AllSky-1242107479-1.xml
# H1L1-MBTA_AllSky-1252502563-1.xml
# H1L1-MBTA_AllSky-1253534746-1.xml
# H1L1-MBTA_AllSky-1252684536-1.xml
# H1L1-MBTA_AllSky-1249484681-1.xml
# H1L1-MBTA_AllSky-1245050022-1.xml
# H1L1-MBTA_AllSky-1250627905-1.xml
# H1L1-MBTA_AllSky-1244372889-1.xml
# H1L1-MBTA_AllSky-1242251296-1.xml
# H1L1-MBTA_AllSky-1250712366-1.xml
# H1L1-MBTA_AllSky-1238685185-1.xml
# H1L1V1-MBTA_AllSky-1243893198-1.xml
# H1L1-MBTA_AllSky-1241940902-1.xml
# H1L1-MBTA_AllSky-1248270649-1.xml
# H1L1-MBTA_AllSky-1239917954-1.xml
# L1V1-MBTA_AllSky-1240168013-1.xml
# H1L1-MBTA_AllSky-1239392783-1.xml
# H1L1V1-MBTA_AllSky-1242429942-1.xml
# H1L1-MBTA_AllSky-1245584947-1.xml
# H1L1-MBTA_AllSky-1248834439-1.xml
# H1L1-MBTA_AllSky-1244715557-1.xml
# H1L1-MBTA_AllSky-1251049007-1.xml
# H1L1-MBTA_AllSky-1249050626-1.xml
# H1L1-MBTA_AllSky-1243257745-1.xml
# skymaps
# H1L1-MBTA_AllSky-1253533222-1.xml
# H1L1-MBTA_AllSky-1250141722-1.xml
# H1L1-MBTA_AllSky-1238770703-1.xml
# H1L1-MBTA_AllSky-1248802992-1.xml
# H1L1-MBTA_AllSky-1240245347-1.xml
# H1L1-MBTA_AllSky-1252325522-1.xml
# H1L1-MBTA_AllSky-1242803163-1.xml
# H1L1-MBTA_AllSky-1240244814-1.xml
# H1L1-MBTA_AllSky-1249591229-1.xml
# H1L1-MBTA_AllSky-1244215683-1.xml
# H1L1-MBTA_AllSky-1244619315-1.xml
# H1L1-MBTA_AllSky-1247768508-1.xml
# H1L1-MBTA_AllSky-1249502272-1.xml
# H1L1-MBTA_AllSky-1245790830-1.xml
# H1L1-MBTA_AllSky-1250082175-1.xml
# H1L1V1-MBTA_AllSky-1241324936-1.xml
# H1L1-MBTA_AllSky-1245257949-1.xml
# H1L1-MBTA_AllSky-1239449956-1.xml
# H1L1-MBTA_AllSky-1249233735-1.xml
# H1L1-MBTA_AllSky-1251319088-1.xml
# H1L1-MBTA_AllSky-1244373358-1.xml
# H1L1-MBTA_AllSky-1251009263-1.xml
# H1L1V1-MBTA_AllSky-1252265870-1.xml
# H1L1-MBTA_AllSky-1239552847-1.xml
# H1L1-MBTA_AllSky-1243972094-1.xml
# H1L1-MBTA_AllSky-1241554397-1.xml
# H1L1-MBTA_AllSky-1241260258-1.xml
# H1L1-MBTA_AllSky-1244980492-1.xml
# H1L1-MBTA_AllSky-1251679783-1.xml
# H1L1-MBTA_AllSky-1251999742-1.xml
# H1L1-MBTA_AllSky-1244636592-1.xml
# H1L1-MBTA_AllSky-1247700761-1.xml
# H1L1-MBTA_AllSky-1246487219-1.xml
# H1L1-MBTA_AllSky-1242287134-1.xml
# H1L1-MBTA_AllSky-1238839747-1.xml
# H1L1-MBTA_AllSky-1250699491-1.xml
# H1L1-MBTA_AllSky-1244818630-1.xml
# H1L1-MBTA_AllSky-1240309408-1.xml
# H1V1-MBTA_AllSky-1249054303-1.xml
# H1V1-MBTA_AllSky-1243874338-1.xml
# H1L1-MBTA_AllSky-1248617394-1.xml
# H1L1-MBTA_AllSky-1247616534-1.xml
# H1L1-MBTA_AllSky-1249216188-1.xml
# H1L1V1-MBTA_AllSky-1241945900-1.xml
# H1L1-MBTA_AllSky-1248376677-1.xml
# H1L1-MBTA_AllSky-1252686781-1.xml
# H1L1-MBTA_AllSky-1251706736-1.xml
# H1L1-MBTA_AllSky-1242825592-1.xml
# H1L1-MBTA_AllSky-1253722987-1.xml
# H1L1-MBTA_AllSky-1250510716-1.xml
# H1L1-MBTA_AllSky-1246849694-1.xml
# H1L1V1-MBTA_AllSky-1253360602-1.xml
# H1L1-MBTA_AllSky-1241131724-1.xml
# H1L1V1-MBTA_AllSky-1242703607-1.xml
# H1L1-MBTA_AllSky-1245855211-1.xml
# H1L1-MBTA_AllSky-1245748049-1.xml
# H1L1-MBTA_AllSky-1250119978-1.xml
# H1L1-MBTA_AllSky-1242280505-1.xml
# H1L1-MBTA_AllSky-1240340350-1.xml
# H1L1-MBTA_AllSky-1252263534-1.xml
# H1L1-MBTA_AllSky-1240761550-1.xml
# L1V1-MBTA_AllSky-1238272667-1.xml
# H1L1-MBTA_AllSky-1251530609-1.xml
# H1L1-MBTA_AllSky-1241094629-1.xml
# H1L1-MBTA_AllSky-1245595187-1.xml
# H1L1V1-MBTA_AllSky-1244948880-1.xml
# H1L1-MBTA_AllSky-1242793805-1.xml
# H1L1-MBTA_AllSky-1247746007-1.xml
# H1L1-MBTA_AllSky-1243167760-1.xml
# H1L1-MBTA_AllSky-1241853220-1.xml
# H1L1-MBTA_AllSky-1247500937-1.xml
# H1L1-MBTA_AllSky-1240057811-1.xml
# H1L1-MBTA_AllSky-1246779793-1.xml
# H1L1-MBTA_AllSky-1249240569-1.xml
# H1L1-MBTA_AllSky-1251313430-1.xml
# H1L1-MBTA_AllSky-1250518275-1.xml
# H1L1-MBTA_AllSky-1247602235-1.xml
# H1L1-MBTA_AllSky-1252064527-1.xml
# H1L1-MBTA_AllSky-1247299487-1.xml
# H1L1-MBTA_AllSky-1241816086-1.xml
# H1L1-MBTA_AllSky-1243081134-1.xml
# H1L1-MBTA_AllSky-1240229379-1.xml
# H1L1-MBTA_AllSky-1238686803-1.xml
# H1L1-MBTA_AllSky-1253032356-1.xml
# H1L1-MBTA_AllSky-1245765880-1.xml
# H1L1-MBTA_AllSky-1244379337-1.xml
# H1L1-MBTA_AllSky-1251048445-1.xml
# H1L1-MBTA_AllSky-1241520730-1.xml
# H1L1-MBTA_AllSky-1253450186-1.xml
# H1L1V1-MBTA_AllSky-1248580941-1.xml
# H1L1-MBTA_AllSky-1253728369-1.xml
# H1L1-MBTA_AllSky-1253326744-1.xml
# H1L1-MBTA_AllSky-1250266840-1.xml
# H1L1-MBTA_AllSky-1238782700-1.xml
# H1L1-MBTA_AllSky-1250174816-1.xml
# H1L1-MBTA_AllSky-1251996593-1.xml
# H1L1-MBTA_AllSky-1246411348-1.xml
# H1L1-MBTA_AllSky-1242459857-1.xml
# H1L1-MBTA_AllSky-1246468691-1.xml
# H1L1V1-MBTA_AllSky-1240190877-1.xml
# H1L1-MBTA_AllSky-1241719652-1.xml
# H1L1-MBTA_AllSky-1249041074-1.xml
# H1L1-MBTA_AllSky-1246787666-1.xml
# H1L1V1-MBTA_AllSky-1252530286-1.xml
# H1V1-MBTA_AllSky-1243908348-1.xml
# H1L1V1-MBTA_AllSky-1241092036-1.xml
# H1L1-MBTA_AllSky-1238412012-1.xml
# H1L1-MBTA_AllSky-1243305426-1.xml
# H1L1-MBTA_AllSky-1247906345-1.xml
# L1V1-MBTA_AllSky-1240513265-1.xml
# H1L1-MBTA_AllSky-1251295370-1.xml
# H1L1-MBTA_AllSky-1253755327-1.xml
# H1L1V1-MBTA_AllSky-1242280001-1.xml
# H1L1V1-MBTA_AllSky-1238482402-1.xml
# H1V1-MBTA_AllSky-1244829281-1.xml
# H1L1-MBTA_AllSky-1240746391-1.xml
# H1L1-MBTA_AllSky-1244984167-1.xml
# H1L1-MBTA_AllSky-1244334860-1.xml
# H1L1-MBTA_AllSky-1253300220-1.xml
# H1L1-MBTA_AllSky-1240155151-1.xml
# H1L1-MBTA_AllSky-1248112066-1.xml
# H1L1-MBTA_AllSky-1240155984-1.xml
# H1L1-MBTA_AllSky-1251825720-1.xml
# H1L1-MBTA_AllSky-1246272532-1.xml
# H1L1-MBTA_AllSky-1245405835-1.xml
# H1L1-MBTA_AllSky-1241471154-1.xml
# H1L1-MBTA_AllSky-1248815899-1.xml
# H1L1-MBTA_AllSky-1249476344-1.xml
# H1L1-MBTA_AllSky-1239635021-1.xml
# H1L1-MBTA_AllSky-1239987421-1.xml
# H1L1-MBTA_AllSky-1248856883-1.xml
# H1L1-MBTA_AllSky-1239533670-1.xml
# H1L1-MBTA_AllSky-1251962784-1.xml
# H1L1-MBTA_AllSky-1245874666-1.xml
# H1L1-MBTA_AllSky-1242431599-1.xml
# H1L1-MBTA_AllSky-1239105874-1.xml
# H1L1-MBTA_AllSky-1245928865-1.xml
# H1L1-MBTA_AllSky-1251056667-1.xml
# pastro
# H1L1-MBTA_AllSky-1252156293-1.xml
# H1L1-MBTA_AllSky-1240762755-1.xml
# H1L1V1-MBTA_AllSky-1240339653-1.xml
# H1L1-MBTA_AllSky-1247317504-1.xml
# H1L1V1-MBTA_AllSky-1252674264-1.xml
# H1L1-MBTA_AllSky-1253293725-1.xml
# H1V1-MBTA_AllSky-1251728353-1.xml
# H1L1-MBTA_AllSky-1249630159-1.xml
# H1L1-MBTA_AllSky-1238616025-1.xml
# H1L1-MBTA_AllSky-1247407392-1.xml
# H1L1-MBTA_AllSky-1239546720-1.xml
# H1L1-MBTA_AllSky-1240853256-1.xml
# H1L1-MBTA_AllSky-1241271788-1.xml
# H1L1-MBTA_AllSky-1253948970-1.xml
# H1L1V1-MBTA_AllSky-1246050877-1.xml
# H1L1-MBTA_AllSky-1247587950-1.xml
# H1L1-MBTA_AllSky-1253914963-1.xml
# H1L1-MBTA_AllSky-1246098980-1.xml
# H1L1-MBTA_AllSky-1245093431-1.xml
# H1L1-MBTA_AllSky-1249816865-1.xml
# H1L1-MBTA_AllSky-1241607842-1.xml
# H1L1-MBTA_AllSky-1246638951-1.xml
# H1L1-MBTA_AllSky-1250570265-1.xml
# H1L1-MBTA_AllSky-1239196938-1.xml
# H1L1-MBTA_AllSky-1245335063-1.xml
# H1L1-MBTA_AllSky-1248185074-1.xml
# H1L1-MBTA_AllSky-1248331528-1.xml
# H1L1-MBTA_AllSky-1244806663-1.xml
# H1L1-MBTA_AllSky-1249494357-1.xml
# H1L1-MBTA_AllSky-1247569544-1.xml
# H1L1-MBTA_AllSky-1246476114-1.xml
# H1L1-MBTA_AllSky-1251010527-1.xml
# H1L1-MBTA_AllSky-1252348387-1.xml
# H1L1-MBTA_AllSky-1252265257-1.xml
# H1L1-MBTA_AllSky-1248603317-1.xml
# H1L1-MBTA_AllSky-1240274059-1.xml
# H1L1-MBTA_AllSky-1245158862-1.xml
# H1L1-MBTA_AllSky-1247690627-1.xml
# H1L1-MBTA_AllSky-1239082262-1.xml
# H1V1-MBTA_AllSky-1253489343-1.xml
# H1L1-MBTA_AllSky-1248759566-1.xml
# H1L1-MBTA_AllSky-1239799209-1.xml
# H1L1-MBTA_AllSky-1244651452-1.xml
# H1L1-MBTA_AllSky-1251016083-1.xml
# H1L1-MBTA_AllSky-1253297272-1.xml
# H1L1-MBTA_AllSky-1241571500-1.xml
# H1L1-MBTA_AllSky-1239527023-1.xml
# H1L1-MBTA_AllSky-1240735110-1.xml
# H1L1-MBTA_AllSky-1253719269-1.xml
# H1L1-MBTA_AllSky-1240960740-1.xml
# H1L1-MBTA_AllSky-1244331430-1.xml
# H1L1-MBTA_AllSky-1246010956-1.xml
# H1L1-MBTA_AllSky-1244490664-1.xml
# H1L1-MBTA_AllSky-1241948467-1.xml
# H1L1-MBTA_AllSky-1244290974-1.xml
# H1L1-MBTA_AllSky-1251026259-1.xml
# H1L1-MBTA_AllSky-1248497942-1.xml
# H1L1V1-MBTA_AllSky-1243475300-1.xml
# H1L1-MBTA_AllSky-1248466772-1.xml
# L1V1-MBTA_AllSky-1249852257-1.xml
# H1L1V1-MBTA_AllSky-1240330591-1.xml
# skymaps
# pastro

# %%
snr_all = snr_21_as + snr_21_gst + snr_21_hm + snr_21_mbta + snr_3_as + snr_3_gst + snr_3_hm + snr_3_mbta
# far_all = far_21_as+far_21_gst+far_21_hm+far_21_mbta+far_3_as+far_3_gst+far_3_hm+far_3_mbta
combined_far_all = combined_far_21_as+combined_far_21_gst+combined_far_21_hm+combined_far_21_mbta+combined_far_3_as+combined_far_3_gst+combined_far_3_hm+combined_far_3_mbta
print(len(snr_all), len(combined_far_all))
# Out:
# 2253 2253

# %% [markdown]
# GWTC2.1 MBTA pipeline has length zero for snr, far and combined far
#
# GWTC 3 MBTA pipelines has 264 snr then zero far and combined far
#
# far had no value in some cases, as we are interested in the combined_far anyway, the far have been removed and the problem appears solved
#
# wrt cWB, in the GWTC3 paper: "We omit the cWB search from our vol-
# ume estimate, since at present any detection of a binary
# merger was corroborated by a detection in the remain-
# ing pipelines"

# %%
fig, ax = plt.subplots(figsize = (9, 6))
sc = ax.scatter(x=snr_all, y=combined_far_all, label='real candidates: combined far')
ax.set_yscale("log")
plt.ylabel('Combined FAR, yr$^-1$')
plt.xlabel('Network matched filter SNR')
plt.semilogy(samples['net_snr'], samples['FAR'], '-', markersize=3, label=r'samples, Lynch $\alpha = 0.18$')
plt.xlim((5,20))
plt.ylim((1e-7,1e6))
# fig.colorbar(sc, label='$p_{astro}$')
plt.legend()
plt.grid()

# %% [markdown]
# Now I need to:
# * combine the two datasets
# * remove duplicates as it says the GWTC3 set contain a subset of GWTC2.1
# * remove those which have saturated

# %%
# combine the lists into a dataframe
data_release_snr_far = pd.DataFrame(list(zip(snr_all, combined_far_all)), columns=['snr', 'combined_far'])
print(len(data_release_snr_far))

# drop duplicates from this dataframe
data_release_snr_far_drop = data_release_snr_far.drop_duplicates()
print(len(data_release_snr_far_drop))
# drop saturated far values from this dataframe
data_release_snr_far_drop_sat = data_release_snr_far_drop.drop_duplicates(subset=['combined_far'], keep='first')
print(len(data_release_snr_far_drop_sat))
# # drop rows close to far = 1
# data_release_snr_far_drop_sat = data_release_snr_far_drop_sat[data_release_snr_far_drop_sat.far < 0.99]
# print(len(data_release_snr_far_drop_sat))

data_release_snr_far_drop_sat.to_csv('all_candidates.csv')
# Out:
# 2253
# 2253
# 2246

# %%
fig, ax = plt.subplots(figsize = (9, 6))
sc = ax.scatter(x=data_release_snr_far_drop_sat['snr'], y=data_release_snr_far_drop_sat['combined_far'], label='real candidates: combined far')
ax.set_yscale("log")
plt.ylabel('FAR, yr$^-1$')
plt.xlabel('Network matched filter SNR')
plt.semilogy(samples['net_snr'], samples['FAR'], '-', markersize=3, label=r'samples, $\alpha = 0.18$')
plt.xlim((5,20))
plt.ylim((1e-7,1e6))
# fig.colorbar(sc, label='$p_{astro}$')
plt.legend()
plt.grid()
plt.savefig('snr_far_relationship.png')

# %%
# we want to fit the snr_to_far relationship to the data and see if a different alpha (or FAR8) comes out
from scipy.optimize import curve_fit

def far_fn_both(snr, FAR8, alpha):
    """Calculate the FAR using the parameterisations from the Lynch paper"""
    FAR = FAR8*np.exp(-(snr-8)/alpha)
    return FAR

parameters, covariance = curve_fit(far_fn_both, data_release_snr_far_drop_sat['snr'], data_release_snr_far_drop_sat['combined_far'])

fit_FAR8_both = parameters[0]
fit_alpha_both = parameters[1]
print(fit_FAR8_both, fit_alpha_both)

fitted_FAR_alpha_FAR8 = far_fn_both(data_release_snr_far_drop_sat['snr'], fit_FAR8_both, fit_alpha_both)
# Out:
# 1102.6636045027296 -163582.31668745013

# %%
# this fit only allows alpha to vary
def far_fn(snr, alpha):
    """Calculate the FAR using the parameterisations from the Lynch paper"""
    FAR = 5500*np.exp(-(snr-8)/alpha)
    return FAR

parameters, covariance = curve_fit(far_fn, data_release_snr_far_drop_sat['snr'], data_release_snr_far_drop_sat['combined_far'])

fit_alpha = parameters[0]
print(fit_alpha)

fitted_FAR_alpha = far_fn(data_release_snr_far_drop_sat['snr'], fit_alpha)
# Out:
# 2.998693322109219

# %%
fig, ax = plt.subplots(figsize = (9, 6))
sc = ax.scatter(x=data_release_snr_far_drop_sat['snr'], y=data_release_snr_far_drop_sat['combined_far'], label='real candidates: combined far', s=6)
ax.set_yscale("log")
plt.ylabel('FAR, yr$^-1$')
plt.xlabel('Network matched filter SNR')
plt.semilogy(samples['net_snr'], samples['FAR'], '-', markersize=3, label=r'Lynch, $\alpha = 0.18$, FAR8=5500 /yr')
plt.semilogy(data_release_snr_far_drop_sat['snr'], fitted_FAR_alpha, '-', markersize=3, label=r'fit, $\alpha = {}$, FAR8 = 5500 /yr'.format(np.round(fit_alpha, 4)))
plt.semilogy(data_release_snr_far_drop_sat['snr'], fitted_FAR_alpha_FAR8, '-', markersize=3, label=r'fit, $\alpha = {}$, FAR8 = {}/yr'.format(np.round(fit_alpha_both,4), np.round(fit_FAR8_both, 10)))
#plt.scatter(x=data_release_snr_far_round_drop_sat['snr'], y=data_release_snr_far_round_drop_sat['far'], label='real candidates: false_alarm_rate', s=6)
plt.xlim((5,25))
plt.ylim((1e-8,1e6))
# fig.colorbar(sc, label='$p_{astro}$')
plt.legend()
plt.grid()
plt.savefig('snr_far_relationship.png')

# %%
def plot_loghist(x, bins):
  hist, bins = np.histogram(x, bins=bins)
  logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
  plt.hist(x, bins=logbins)
  plt.xscale('log')
plot_loghist(data_release_snr_far_drop_sat['combined_far'], 50)
plt.xlabel('FAR')
# Out:
# Text(0.5, 0, 'FAR')

# %% [markdown]
# Some notes:
# * the above fits are to the combined far not to the far
# * the FAR8 = 5500 looks like it's way off this dataset
# * my FAR cut to remove the saturated values also doesn't look strong enough, the fit is heavily skewed towards these
# * the SNRs from my samples are a combined SNR for HLV whereas the FAR and SNR from the true data are a mixture of combinations of HLV and single detectors
#     * **what is the relationship between FAR and combined FAR?**
#         *  it mostly looks like it's a shift from the plots but I would expect single detector candidates to have the same FAR and combined_FAR
# * what is the pyCBC broad SNR caluclation
#
# from GWTC3:
#
# "PyCBC Live uses a more computationally simple ranking statistic than the one used in offline analyses. This simpler ranking statistic is used in order to maintain speed in a low latency en-vironment and does not contain all of the information used in the offline statistic. The reduced χ2-reweighted SNR [21] and a sine–Gaussian veto [386, 606] are used
# to assess significance of single-detector triggers. These
# single-detector triggers are then tested for coincidence,
# and the coincident ranking statistic is calculated. The
# ranking statistic is compared to the time-shifted back-
# ground from five hours of data to estimate FAR."
#
# from https://pycbc.org/pycbc/latest/html/formats/hdf_format.html?highlight=combined
# * looks like it describs the sngl_inspiral section of the xml files
# * I have checked these SNRs against the coinc_inspiral which is just the quadratic sum
#     * these snrs are the mangitude of the complex SNR
# * "we keep its coincidence if its ranking statistic (newSNR) > 8.5"
#     * these files have SNR<8.5 suggesting it's not newSNR
#
# far = [lal.YRJUL_SI * coinc_results['foreground/ifar']]$^{-1}$ = combined_far, where lal.YRJUL_SI is the julian year
#
# false_alarm_rate = 0
#
# It looks like these files are built from https://pycbc.org/pycbc/latest/html/_modules/pycbc/io/live.html, and more info at https://pycbc.org/pycbc/latest/html/_modules/pycbc/io/hdf.html
# * it looks like far is actually the fap, false alarm probability, which makes sense as the values have a maximum of 1
# * which means I want combined_far whis is 1/ifar
#
# false_alarm_rate = coinc_event_vals['fap']
#
# combined_far = [coinc_event_vals['ifar']]$^{-1}$

# %% [markdown]
# ### Next
# These fits are rather poor so let's try different ideas:
# * fit in log space
# * fit a power law
# * look into scipy curve_fit and see what the fitting entails
#     * uses non-linear least squares

# %%
# trimming
# get the real signals as a list
real_snr = data_release['network_matched_filter_snr'].tolist()
real_far = data_release['far'].tolist()
# combine the lists into a dataframe
snr_all_real = snr + snr_21 + real_snr
combined_far_all_real = combined_far + combined_far_21 + real_far
data_release_snr_far_real = pd.DataFrame(list(zip(snr_all_real, combined_far_all_real)), columns=['snr', 'combined_far'])
print(len(data_release_snr_far_real))

# drop duplicates from this dataframe
# can remove this first drop duplicates
real_data_release_snr_far_drop = data_release_snr_far_real.drop_duplicates()
print(len(real_data_release_snr_far_drop))
# drop saturated far values from this dataframe
real_data_release_snr_far_drop_sat = real_data_release_snr_far_drop.drop_duplicates(subset=['combined_far'], keep='first')
print(len(real_data_release_snr_far_drop_sat))
# drop rows with a far over 2, choice of 2 has no basis, the candated events are <2 /day, this cut is <2/yr
real_data_release_snr_far_drop_sat = real_data_release_snr_far_drop_sat[real_data_release_snr_far_drop_sat.combined_far <2]
print(len(real_data_release_snr_far_drop_sat))


# fitting
# fitting the function with both free parameters
parameters, covariance = curve_fit(far_fn_both, real_data_release_snr_far_drop_sat['snr'], real_data_release_snr_far_drop_sat['combined_far'])

fit_FAR8_both = parameters[0]
fit_alpha_both = parameters[1]
print(fit_FAR8_both, fit_alpha_both)
# feed the function the snr's and the fitted parameters
fitted_FAR_alpha_FAR8 = far_fn_both(real_data_release_snr_far_drop_sat['snr'], fit_FAR8_both, fit_alpha_both)

# the function with just one free parameter
parameters1, covariance1 = curve_fit(far_fn, real_data_release_snr_far_drop_sat['snr'], real_data_release_snr_far_drop_sat['combined_far'])

fit_alpha = parameters1[0]
print(fit_alpha)

fitted_FAR_alpha = far_fn(real_data_release_snr_far_drop_sat['snr'], fit_alpha)


# plotting
fig, ax = plt.subplots(figsize = (9, 6))
sc = ax.scatter(x=real_data_release_snr_far_drop_sat['snr'], y=real_data_release_snr_far_drop_sat['combined_far'], label='real and candidates: combined far', s=6)
ax.set_yscale("log")
plt.ylabel('FAR, yr$^-1$')
plt.xlabel('Network matched filter SNR')
plt.semilogy(samples['net_snr'], samples['FAR'], '-', markersize=3, label=r'Lynch, $\alpha = 0.18$, FAR8=5500 /yr')
plt.semilogy(real_data_release_snr_far_drop_sat['snr'], fitted_FAR_alpha, '-', markersize=3, label=r'fit, $\alpha = {}$, FAR8 = 5500 /yr'.format(np.round(fit_alpha, 4)))
plt.semilogy(real_data_release_snr_far_drop_sat['snr'], fitted_FAR_alpha_FAR8, '-', markersize=3, label=r'fit, $\alpha = {}$, FAR8 = {}/yr'.format(np.round(fit_alpha_both,4), np.round(fit_FAR8_both, 10)))

plt.xlim((5,25))
plt.ylim((1e-8,1e3))
# fig.colorbar(sc, label='$p_{astro}$')
plt.legend()
plt.grid()
plt.savefig('snr_far_relationship_real_and_candidates.png')
# Out:
# 747
# 747
# 703
# 85
# 1.01537516980206 0.9477480993104601
# 0.43076168242541274

# %% [markdown]
# ### Using the parameterisation
# I can proceed with this parameterisation for now and can always come back and update.
# So let's now convert SNRs into FARs.
#
# The above fit gives FAR8 to be 1.015, let's call this 1. $\alpha = 0.9477$ lets call this 0.95.
#
# **have I introduced some sort of bias by cutting my FARs?**

# %%
# my snr to far function
def far_fn(snr, FAR8=1, alpha=0.95):
    """Calculate the FAR using the parameterisations from the Lynch paper"""
    FAR = FAR8*np.exp(-(snr-8)/alpha)
    return FAR

# %%
samples['FAR'] = far_fn(samples['net_snr'])
samples.to_csv('params_inc_FAR.csv')

# %%
samples.head()
# Out:
#       mass_1  mass_ratio       a_1       a_2  cos_tilt_1  cos_tilt_2  \
# 0  14.206189    0.753297  0.084464  0.150304   -0.261760    0.392646
# 1   7.631592    0.987168  0.301969  0.514466   -0.610410   -0.613718
# 2   6.088737    0.993740  0.235612  0.437827    0.873063    0.821194
# 3  13.368498    0.656860  0.519649  0.126563    0.212090   -0.385168
# 4  23.997822    0.479771  0.313633  0.007355    0.270814    0.404514
#
#    redshift     mass_2   chi_eff    tilt_1  ...    V1_snr  theta_jn       psi  \
# 0  0.906271  10.701485  0.012746  1.835642  ...  1.249735  0.478923  2.518351
# 1  1.837756   7.533664 -0.249606  2.227374  ...  0.376991  2.060811  2.176761
# 2  2.090188   6.050621  0.282381  0.509347  ...  0.782588  2.746061  0.839684
# 3  1.802572   8.781230  0.047193  1.357083  ...  0.249479  1.376382  2.458206
# 4  1.759925  11.513460  0.058363  1.296558  ...  0.578285  1.917434  0.655696
#
#       phase        ra       dec    phi_12    phi_jl   net_snr          FAR
# 0  4.208321  3.068214  0.029949  1.709171  6.212235  4.715177    31.744143
# 1  3.695127  3.062258  0.902357  5.343215  3.462008  0.762437  2035.480706
# 2  2.333354  5.323210  1.533282  3.987185  4.133948  1.630003   816.690300
# 3  0.808485  3.241303  0.622675  1.394951  0.676842  0.953321  1664.960105
# 4  5.435143  1.227290  1.416742  0.354682  3.028431  1.492217   944.162258
#
# [5 rows x 33 columns]
